# %% [markdown]
# # **Набор данных о здоровье сна и образе жизни**
#
# **О датасете**
#
# Набор данных о здоровье сна и образе жизни содержит 400 строк и 13 столбцов, охватывающих широкий спектр переменных, связанных со сном и повседневными привычками. Он включает в себя такие данные, как пол, возраст, профессия, продолжительность и качество сна, уровень физической активности, уровень стресса, категория ИМТ, кровяное давление, частота сердечных сокращений, ежедневные шаги и наличие или отсутствие нарушений сна.
#
# **Основные характеристики набора данных:**
#
#
# *  **Person ID** (Идентификатор пользователя): Идентификатор для каждого человека.
# *   **Gender** (Пол): Пол человека (мужчина/женщина).
# *   **Age** (Возраст): Возраст человека в годах.
# *   **Occupation** (Род занятий): Род занятий или профессия человека.
# *   **Sleep Duration (hours)** (Продолжительность сна (в часах)): Количество часов, которое человек спит в сутки.
# *   **Quality of Sleep (scale: 1-10)** (Качество сна (шкала от 1 до 10)): Субъективная оценка качества сна в диапазоне от 1 до 10.
# *   **Physical Activity Level (minutes/day)** (Уровень физической активности (минуты в день)): Количество минут, которые человек ежедневно уделяет физической активности.
# *   **Stress Level (scale: 1-10)** (Уровень стресса (шкала от 1 до 10)): субъективная оценка уровня стресса, испытываемого человеком, в диапазоне от 1 до 10.
# *   **BMI Category** (Категория ИМТ): Категория ИМТ человека (например, недостаточный вес, нормальный, избыточный вес с избыточной массой тела).
# *   **Blood Pressure (systolic/diastolic)** (Артериальное давление (систолическое/диастолический давление)): Измерение артериального давления человека, показывающее превышение систолического давления над диастолическим давлением.
# *   **Heart Rate (bpm)** (Частота сердечных сокращений (чсс)): Частота сердечных сокращений человека в состоянии покоя в ударах в минуту.
# *   **Daily Steps** (Количество шагов в день): Количество шагов, которые человек делает за день.
# *   **Sleep Disorder** (Нарушение сна): Наличие или отсутствие у человека нарушений сна (отсутствие таковых, бессонница, апноэ во сне).
#
# **Подробная информация о нарушениях сна:**
#
# **Нет:** у пациента нет каких-либо специфических нарушений сна.
#
# **Бессонница:** Пациент испытывает трудности с засыпанием или продолжительным пребыванием во сне, что приводит к неадекватному или некачественному сну.
#
# **Апноэ во сне:** Человек страдает от пауз в дыхании во время сна, что приводит к нарушению режима сна и потенциальному риску для здоровья.

# %%
# установка зависимостей
# !pip install pandas matplotlib seaborn

# %%
# импортируем библиотеки
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
PATH_TO_FILE: str = '/content/Sleep_health_and_lifestyle_dataset.csv' # Загрузка набора данных
## p.s. в левой панеле нажать на папку и перетащить туда файл,
## а wince.csv заменить на свой вариант (ПКМ -> копировать путь)

df = pd.read_csv(PATH_TO_FILE) # функция превращение данных из CSV в DataFrame

# %%
# вывод датафрейма
df # p.s. обычно переменную с набором данных называют df, придерживайтесь этого наименования в дальнейшем
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
# Вывод первых 5 строк
df.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# ...

# %%
# вывод 5 последних строк
df.tail()
# Out:
#      Person ID  Gender  Age Occupation  Sleep Duration  Quality of Sleep  \
# 369        370  Female   59      Nurse             8.1                 9
# 370        371  Female   59      Nurse             8.0                 9
# 371        372  Female   59      Nurse             8.1                 9
# 372        373  Female   59      Nurse             8.1                 9
# 373        374  Female   59      Nurse             8.1                 9
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# 369                       75             3   Overweight         140/95
# 370                       75             3   Overweight         140/95
# 371                       75             3   Overweight         140/95
# 372                       75             3   Overweight         140/95
# 373                       75             3   Overweight         140/95
#
#      Heart Rate  Daily Steps Sleep Disorder
# 369          68         7000    Sleep Apnea
# ...

# %%
# Информация о наборе данных
df.info() # инфо о датасете название колонки, сколько не пропущенных, дефолтный тип данных
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
# Статистический разбор
df.describe() # include=all (вывод включая категориальные)
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               374.000000    374.000000  374.000000    374.000000
# mean                 59.171123      5.385027   70.165775   6816.844920
# std                  20.830804      1.774526    4.135676   1617.915679
# min                  30.000000      3.000000   65.000000   3000.000000
# ...

# %%
# преобразование в категориальные

df['Gender'] = df['Gender'].astype('category')
df['Quality of Sleep'] = df['Quality of Sleep'].astype('category')
df['Stress Level'] = df['Stress Level'].astype('category')
df['BMI Category'] = df['BMI Category'].astype('category')
df['Sleep Disorder'] = df['Sleep Disorder'].astype('category')
df['Person ID'] = df['Person ID'].astype('object')

# %%
# Вывод колонок в наборе данных
df.columns
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder'],
#       dtype='object')

# %% [markdown]
# ## Определение типов переменных

# %%
# Список столбцов и их типов данных
print(df.dtypes)
# Out:
# Person ID                    object
# Gender                     category
# Age                           int64
# Occupation                   object
# Sleep Duration              float64
# Quality of Sleep           category
# Physical Activity Level       int64
# Stress Level               category
# BMI Category               category
# Blood Pressure               object
# Heart Rate                    int64
# Daily Steps                   int64
# Sleep Disorder             category
# dtype: object

# %% [markdown]
# - Числовые переменные обычно имеют тип int64 или float64.
# - Категориальные переменные могут иметь тип object или int (например метки класса)

# %% [markdown]
# ## Статистический разбор данных

# %% [markdown]
# 1. **Посчитайте количество уникальных значений для каждой переменной:**

# %%
# Количество уникальных значений
for column in df.columns:
    print(f'{column}: {df[column].nunique()} уникальных значений')
# Out:
# Person ID: 374 уникальных значений
# Gender: 2 уникальных значений
# Age: 31 уникальных значений
# Occupation: 11 уникальных значений
# Sleep Duration: 27 уникальных значений
# Quality of Sleep: 6 уникальных значений
# Physical Activity Level: 16 уникальных значений
# Stress Level: 6 уникальных значений
# BMI Category: 4 уникальных значений
# Blood Pressure: 25 уникальных значений
# Heart Rate: 19 уникальных значений
# Daily Steps: 20 уникальных значений
# Sleep Disorder: 2 уникальных значений

# %% [markdown]
# **⏰ задача**
#
# Определить типы переменных
# - номинальные переменные (не имеют порядка и сравнения)
# - порядковые пиеременные (имеют порядок, но не имеют смысла мат операции)
# - числовые непрерывные переменные (имеют порядок, есть смысл мат операций)
#
# Вывести статистику для числовых и для категоиральных перменных раздельно.
#
# p.s. если существует несколько гипотез к какому типу относительно одна и та же переменной - объяснить почему

# %%
df.describe()
# Out:
#               Age  Sleep Duration  Physical Activity Level  Heart Rate  \
# count  374.000000      374.000000               374.000000  374.000000
# mean    42.184492        7.132086                59.171123   70.165775
# std      8.673133        0.795657                20.830804    4.135676
# min     27.000000        5.800000                30.000000   65.000000
# 25%     35.250000        6.400000                45.000000   68.000000
# 50%     43.000000        7.200000                60.000000   70.000000
# 75%     50.000000        7.800000                75.000000   72.000000
# max     59.000000        8.500000                90.000000   86.000000
#
#         Daily Steps
# count    374.000000
# mean    6816.844920
# std     1617.915679
# min     3000.000000
# 25%     5600.000000
# 50%     7000.000000
# 75%     8000.000000
# max    10000.000000

# %%
df.describe(include='all')
# Out:
#         Person ID Gender         Age Occupation  Sleep Duration  \
# count       374.0    374  374.000000        374      374.000000
# unique      374.0      2         NaN         11             NaN
# top         374.0   Male         NaN      Nurse             NaN
# freq          1.0    189         NaN         73             NaN
# mean          NaN    NaN   42.184492        NaN        7.132086
# std           NaN    NaN    8.673133        NaN        0.795657
# min           NaN    NaN   27.000000        NaN        5.800000
# 25%           NaN    NaN   35.250000        NaN        6.400000
# 50%           NaN    NaN   43.000000        NaN        7.200000
# 75%           NaN    NaN   50.000000        NaN        7.800000
# max           NaN    NaN   59.000000        NaN        8.500000
#
#         Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# count              374.0               374.000000         374.0          374
# ...

# %% [markdown]
# Определение типов переменных
#
# # Номинальные переменные (не имеют порядка и сравнения):
#
# *   Person ID (Идентификатор пользователя)
# *   Gender (Пол)
# *   Occupation (Род занятий)
# *   BMI Category (Категория ИМТ)
# *   Blood Pressure (systolic/diastolic) (Артериальное давление (систолическое/диастолический давление))
# *   Sleep Disorder (Нарушение сна)
#
# # Порядковые переменные (имеют порядок, но не имеют смысла мат операции):
#
# *   Quality of Sleep (scale: 1-10) (Качество сна (шкала от 1 до 10))
# *   Stress Level (scale: 1-10) (Уровень стресса (шкала от 1 до 10))
#
# # Числовые непрерывные переменные (имеют порядок, есть смысл мат операций):
#
# *   Age (Возраст)
# *   Sleep Duration (hours) (Продолжительность сна (в часах))
# *   Physical Activity Level (minutes/day) (Уровень физической активности (минуты в день))
# *   Heart Rate (bpm) (Частота сердечных сокращений (чсс))
# *   Daily Steps (Количество шагов в день)

# %% [markdown]
# ## **4. Визуализация распределения переменных**
#
# ### **Описание:**
# Создайте визуализации для понимания распределения числовых и категориальных переменных.
#
# ### **Шаги:**

# %% [markdown]
# 1. **Гистограмма для числовых переменных:**

# %%
sns.histplot(df['Sleep Duration'], kde=True)
plt.title('Распределение Sleep Duration')
plt.xlabel('Sleep Duration')
plt.ylabel('Частота')
plt.show()

# %%
#ниже код для оптимизации вывода всех числовых переменных
num_cols = df.select_dtypes(include='int').columns # если есть int чиловая переменная либо + ['col1', 'col2'], либо такие колонки преобразовать во flaot
fig, axes = plt.subplots(1, len(num_cols), figsize=(6 * len(num_cols), 4))

for ax, col in zip(axes, num_cols):
    sns.histplot(df[col], kde=True, ax=ax)
    ax.set_title(f'Распределение {col}')
    ax.set_xlabel(col)
    ax.set_ylabel('Частота')

plt.tight_layout()
plt.show()

# %% [markdown]
# Описание графиков:
# Распределение ненормальное

# %% [markdown]
# ![изображение_2025-10-31_220757746.png](data:image/png;base64,...)

# %% [markdown]
# **задача ⏰**
#
# Описать вывод графиков.
# - Является ли распределение нормальным или отлично от него?
# - Концентрация большинства значений
# - если есть категориальная переменная, то с помощью параметры hue попробовать предсказать значение категориальный переменной (пример с диоксидом серы и типом вина)
#
# p.s. 3-5 самых показательных примеров.

# %%
sns.histplot(df, x="Sleep Duration", kde=True, hue='Sleep Disorder')
plt.title('Распределение Нарушение сна')
plt.xlabel('Продолжительность сна (в часах)')
plt.ylabel('Нарушение сна')
plt.show()

# %% [markdown]
# Предсказание:
#
# - если продолжительность сна от 6 до 7 часов в день, велика вероятность, что наступит бессоница;
#
# - если продолжительность сна больше 7 часов, велика вероятность Апноэ во сне.

# %%
sns.histplot(df, x="Age", kde=True, hue='Sleep Disorder')
plt.title('Распределение Нарушение сна')
plt.xlabel('Возраст')
plt.ylabel('Нарушение сна')
plt.show()

# %% [markdown]
# Предсказание:
#
# - если возраст от 40 до 50 лет, велика вероятность, что наступит бессоница;
#
# - если возраст от 45 до 60 лет, велика вероятность Апноэ во сне.

# %%
sns.histplot(df, x="Physical Activity Level", kde=True, hue='Sleep Disorder')
plt.title('Распределение Нарушение сна')
plt.xlabel('Уровень физической активности (минуты в день)')
plt.ylabel('Нарушение сна')
plt.show()

# %% [markdown]
# Предсказание:
#
# - если уровень физической активности от 40 до 50 мин/д, велика вероятность, что наступит бессоница;
#
# - если уровень физической активности от 65 мин/д, велика вероятность Апноэ во сне.

# %%
sns.histplot(df, x="Daily Steps", kde=True, hue='Sleep Disorder')
plt.title('Распределение Нарушение сна')
plt.xlabel('Количество шагов в день')
plt.ylabel('Нарушение сна')
plt.show()

# %%
sns.histplot(df, x="Heart Rate", kde=True, hue='Sleep Disorder')
plt.title('Распределение Нарушение сна')
plt.xlabel('Частота сердечных сокращений (чсс)')
plt.ylabel('Нарушение сна')
plt.show()

# %% [markdown]
# 2. **Столбчатая диаграмма для категориальной переменной `Class`:**

# %%
# ниже код для оптимизации вывода всех категориальных переменных
num_cols = df.select_dtypes(include='category').columns # или object
fig, axes = plt.subplots(1, len(num_cols), figsize=(6 * len(num_cols), 4))

for ax, col in zip(axes, num_cols):
    sns.histplot(df[col], kde=True, ax=ax)
    ax.set_title(f'Распределение {col}')
    ax.set_xlabel(col)
    ax.set_ylabel('Частота')

plt.tight_layout()
plt.show()

# %% [markdown]
# **задача ⏰**
#
# Описать вывод графиков.
# - в каких значениях концентрируентся переменная?
# - если есть категориальная переменная, то с помощью параметры hue попробовать предсказать значение категориальный переменной (пример с диоксидом серы и типом вина)

# %%
sns.countplot(x='Gender', data=df, hue='Sleep Disorder')
plt.title('Распределение Нарушение сна')
plt.xlabel('пол')
plt.ylabel('Нарушение сна')
plt.show()

# %% [markdown]
# Предсказание:
#
# - у женщин вероятность Апноэ во сне больше, чем у мужин;
#
# - бессоницей страдают все одинаково независимо от пола.

# %%
sns.countplot(x='Quality of Sleep', data=df, hue='Sleep Disorder')
plt.title('Распределение Нарушение сна')
plt.xlabel('Качество сна (шкала от 1 до 10)')
plt.ylabel('Нарушение сна')
plt.show()

# %% [markdown]
# Предсказание:
#
# - у людей с хорошим качеством сна велика вероятность Апноэ во сне.

# %%
sns.countplot(x='Stress Level', data=df, hue='Sleep Disorder')
plt.title('Распределение Нарушение сна')
plt.xlabel('Уровень стресса (шкала от 1 до 10)')
plt.ylabel('Нарушение сна')
plt.show()

# %%
sns.countplot(x='BMI Category', data=df, hue='Sleep Disorder')
plt.title('Распределение Нарушение сна')
plt.xlabel('Категория ИМТ')
plt.ylabel('Нарушение сна')
plt.show()

# %% [markdown]
# Предсказание:
#
# у людей с ожирением велика вероятность как Апноэ во сне, так и бессоницы.

# %% [markdown]
# **Боксплот для числовой переменной:**

# %%
sns.boxplot(x=df['Sleep Duration'])
plt.title('Продолжительность сна (в часах)')
plt.xlabel('Продолжительность сна (в часах)')
plt.show()

# %%
num_cols = df.select_dtypes(include='int').columns # если есть int чиловая переменная либо + ['col1', 'col2'], либо такие колонки преобразовать во flaot
fig, axes = plt.subplots(1, len(num_cols), figsize=(6 * len(num_cols), 4))

for ax, col in zip(axes, num_cols):
    sns.boxplot(df[col], ax=ax)
    ax.set_title(f'Распределение {col}')
    ax.set_xlabel(col)
    ax.set_ylabel('Частота')

plt.tight_layout()
plt.show()

# %%
sns.boxplot(df, x="Age", y="Sleep Disorder", hue='Sleep Disorder')
# Out:
# <Axes: xlabel='Age', ylabel='Sleep Disorder'>

# %% [markdown]
# Выбросы: есть Heart Rate (bpm) (Частота сердечных сокращений (чсс))
#
# Предсказание:
#
# - если возраст от 40 до 50 лет, велика вероятность, что наступит бессоница;
#
# - если возраст от 45 до 60 лет, велика вероятность Апноэ во сне.

# %% [markdown]
# **задача ⏰**
#
# Описать вывод графиков.
# - Есть ли выбросы?
# - если есть категориальная переменная, то с помощью параметры hue попробовать предсказать значение категориальный переменной (пример с диоксидом серы и типом вина). Определить различия по медиане

# %% [markdown]
# **Постройте корреляционную матрицу для всех числовых переменных и визуализируйте её с помощью тепловой карты:**

# %% [markdown]
# **если ValueError**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    object
#  1   Gender                   374 non-null    category
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    category
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    category
#  8   BMI Category             374 non-null    category
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    category
# dtypes: category(5), float64(1), int64(4), object(3)
# ...

# %%
# Если будут ошибки ValueError из-за could not conver string to float
df = df.drop('Person ID', axis=1)
df = df.drop('Occupation', axis=1)
df = df.drop('Blood Pressure', axis=1)
df = df.drop('Gender', axis=1)
df = df.drop('Quality of Sleep', axis=1)
df = df.drop('Stress Level', axis=1)
df = df.drop('BMI Category', axis=1)
df = df.drop('Sleep Disorder', axis=1)
# найти колонку, из-за которой ничего не получается,
# можно найти по object из df.info()

# %%
# Корреляционная матрица
correlation_matrix = df.corr()

# Визуализация тепловой карты
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Корреляционная матрица')
plt.show()

# %% [markdown]
# Сильную положительную корреляцию имеют Physical Activity Level (minutes/day) (Уровень физической активности (минуты в день)) и Daily Steps (Количество шагов в день) = 0.77
#
# небольшую положительную корреляцию имеют возраст и Sleep Duration (hours) (Продолжительность сна (в часах)) = 0,34
#
# небольшую слабую корреляцию имеют Heart Rate (bpm) (Частота сердечных сокращений (чсс)) и Sleep Duration (hours) (Продолжительность сна (в часах)) =-0,52

# %% [markdown]
# **задача ⏰**
#
# Интерпертировать полученный результат:
# - Какие переменные не коррелируют?
# - Какие переменные имеют сильную положительную корреляцию?
# - Какие переменные имеют сильную слабую корреляцию?
#
# p.s. сильная корреляция считаем abs(corr_coef) >= 0.7
